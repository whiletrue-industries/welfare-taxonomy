# %%
from google.oauth2.credentials import Credentials
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.http import MediaIoBaseDownload
import os.path
import pickle
from docx import Document
import io
import csv
import re

# %%
SCOPES = ['https://www.googleapis.com/auth/drive', 'https://www.googleapis.com/auth/documents.readonly']
FOLDER_ID = '1HJG2GJ_flNop6bb8n5JORhb0KKlCvuHz'

# %%
def authenticate():
    creds = None
    # Token.pickle stores the user's credentials
    if os.path.exists('token.pickle'):
        with open('token.pickle', 'rb') as token:
            creds = pickle.load(token)
    # If no valid credentials, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        with open('token.pickle', 'wb') as token:
            pickle.dump(creds, token)
    return creds


creds = authenticate()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=523587390725-5b4deohlkhi0grlevmrci0sko9e76l8b.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A65198%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocuments.readonly&state=G69mJ5J1LkpVDdfcN3K9HcgYRrXrU8&access_type=offline

# %%
def list_files(service, folder_id):
    results = service.files().list(
        q=f"'{folder_id}' in parents and trashed=false",
        pageSize=1000,
        fields="nextPageToken, files(id, name, mimeType, webViewLink)").execute()
    items = results.get('files', [])
    return items

def recurse_folders(service, folder_id, path=""):
    items = list_files(service, folder_id)
    names = dict()
    for item in items:
        name = item['name']
        if item['mimeType'] not in ('application/vnd.google-apps.folder', 'application/vnd.google-apps.document'):
            if '.' in name[-5:]:
                name = name[:name.rfind('.')].strip()
        if '~$' in name:
            continue
        name = name.strip()
        copies = names.setdefault(name, [])
        copies.append(item)
    # for k in sorted(names.keys()):
    #     print(f"{path}{k}")
    copied = False
    for name, items in names.items():
        gdocs = [item for item in items if item['mimeType'] == 'application/vnd.google-apps.document']
        words = [item for item in items if item['mimeType'] in (
            'application/vnd.openxmlformats-officedocument.wordprocessingml.document',
            'application/msword'
        )]
        if words and not gdocs:
            print(f"Converting {path}/{words[0]['name']} to Google Docs.... ({name})")
            try:
                service.files().copy(fileId=words[0]['id'], body={'name': name, 'mimeType': 'application/vnd.google-apps.document'}).execute()
                copied = True
            except:
                print(f"Failed to converte{path}/{words[0]['name']} [{words[0]['mimeType']}] to Google Docs")
    if copied:
        yield from recurse_folders(service, folder_id, path)
    else:
        for name, items in names.items():
            gdocs = [item for item in items if item['mimeType'] == 'application/vnd.google-apps.document']
            folders = [item for item in items if item['mimeType'] == 'application/vnd.google-apps.folder']
            if gdocs:
                yield dict(id=gdocs[0]['id'], name=name, link=gdocs[0]['webViewLink'], path=path)
            elif folders:
                yield from recurse_folders(service, folders[0]['id'], path + name + "/")

service = build('drive', 'v3', credentials=creds)
docs = list(recurse_folders(service, FOLDER_ID))
print(f"Found {len(docs)} documents")
# Out:
# Converting /מדיניות הטיפול בנוצץ.msg to Google Docs.... (מדיניות הטיפול בנוצץ)
# Failed to converte/מדיניות הטיפול בנוצץ.msg [application/msword] to Google Docs
# Converting /נוהללטיפולבפניותהציבור (2).doc to Google Docs.... (נוהללטיפולבפניותהציבור (2))
# Failed to converte/נוהללטיפולבפניותהציבור (2).doc [application/msword] to Google Docs
# Converting 5.27//תעס מדיניות השירות לעיוור - 6.8הערות נוספות של אסא.msg to Google Docs.... (תעס מדיניות השירות לעיוור - 6.8הערות נוספות של אסא)
# Failed to converte5.27//תעס מדיניות השירות לעיוור - 6.8הערות נוספות של אסא.msg [application/msword] to Google Docs
# Converting 5.27//הערות אסא להוראה.msg to Google Docs.... (הערות אסא להוראה)
# Failed to converte5.27//הערות אסא להוראה.msg [application/msword] to Google Docs
# Converting 1.42//RE טיוטת נוהל  טיפול בילודים ומשפחותיהם של משרד הבריאות.msg to Google Docs.... (RE טיוטת נוהל  טיפול בילודים ומשפחותיהם של משרד הבריאות)
# Failed to converte1.42//RE טיוטת נוהל  טיפול בילודים ומשפחותיהם של משרד הבריאות.msg [application/msword] to Google Docs
# Converting 1.34//אישור נועם לתעס.msg to Google Docs.... (אישור נועם לתעס)
# Failed to converte1.34//אישור נועם לתעס.msg [application/msword] to Google Docs
# Converting 3.41//26.2.2017.docx to Google Docs.... (26.2.2017)
# Failed to converte3.41//26.2.2017.docx [application/vnd.openxmlformats-officedocument.wordprocessingml.document] to Google Docs
# Converting 3.41//30.11.16.docx to Google Docs.... (30.11.16)
# Failed to converte3.41//30.11.16.docx [application/vnd.openxmlformats-officedocument.wordprocessingml.document] to Google Docs
# Converting 3.41//דירות מעבר לנשים 3.41.docx to Google Docs.... (דירות מעבר לנשים 3.41)
# Failed to converte3.41//דירות מעבר לנשים 3.41.docx [application/vnd.openxmlformats-officedocument.wordprocessingml.document] to Google Docs
# Converting 3.41//24.8.16.docx to Google Docs.... (24.8.16)
# Failed to converte3.41//24.8.16.docx [application/vnd.openxmlformats-officedocument.wordprocessingml.document] to Google Docs
# Converting 3.41//18.8.16.docx to Google Docs.... (18.8.16)
# Failed to converte3.41//18.8.16.docx [application/vnd.openxmlformats-officedocument.wordprocessingml.document] to Google Docs
# Converting 6.8//הערות אסא להוראה.msg to Google Docs.... (הערות אסא להוראה)
# Failed to converte6.8//הערות אסא להוראה.msg [application/msword] to Google Docs
# Converting 16.3//10112015מענים לפרט ולמשפחה 3 16 ננורית.msg to Google Docs.... (10112015מענים לפרט ולמשפחה 3 16 ננורית)
# Failed to converte16.3//10112015מענים לפרט ולמשפחה 3 16 ננורית.msg [application/msword] to Google Docs
# Converting 9.3//FW נוהל טיפול בבני נוער במסגרת מיתר.msg to Google Docs.... (FW נוהל טיפול בבני נוער במסגרת מיתר)
# Failed to converte9.3//FW נוהל טיפול בבני נוער במסגרת מיתר.msg [application/msword] to Google Docs
# Found 679 documents

# %%
DEFS = re.compile(r'\bהגדרות\b|\bה ג ד ר ו ת\b', re.IGNORECASE)
SPACES = re.compile(r' +')

def get_document_contents(service, document_id):
    doc = service.documents().get(documentId=document_id).execute()
    content = doc.get('body').get('content')
    return content

def find_definitions_section(contents, debug=False):
    definitions = []
    in_definitions = False
    in_definitions_digit = None
    in_definitions_errors = 0
    stop = False
    count = 10000
    for element in contents:
        if stop:
            break
        text = ''
        if 'paragraph' in element:
            if stop:
                break
            paragraph = element['paragraph']
            elements = paragraph.get('elements')
            # style = paragraph['paragraphStyle']['namedStyleType']
            for elem in elements:
                if 'textRun' in elem:
                    elem_text = elem['textRun']['content'].replace('\x0b', '\n').replace('\xa0', '')
                    text += elem_text
        text = text.replace('\x0b', '\n').replace('\x0a', '\n').replace('\x0d', '')
        text = SPACES.sub(' ', text)
        text = text.split('\n')
        for ptext in text:
            ptext = ptext.strip()
            if not ptext:
                continue
            count -= len(ptext)
            if count < 0 and not in_definitions:
                stop = True
                break
            if debug:
                print(f"ZZZ: {ptext!r}, {DEFS.search(ptext)}, {len(ptext)}")
            # print(">>>>>", style, ptext[:30])
            if DEFS.search(ptext) and len(ptext) < 15:
                in_definitions = True
                if ptext[0].isdigit() or ptext[1] == '.':
                    in_definitions_digit = ptext[0]
                if debug:
                    print(f'DDDDD {ptext!r}\n--- {in_definitions_digit!r}')
                continue
            if ' הגדרות' in ptext:
                print(f'ERROR: Found "הגדרות" in {ptext!r}')
            if ' ה ג ד ר ו ת' in ptext:
                print(f'ERROR: Found "ה ג ד ר ו ת" in {ptext!r}')

            if in_definitions:
                # if in_definitions_style and 'HEADER' in paragraph['paragraphStyle']['namedStyleType']:
                #     # Check if we encounter another heading after starting definitions
                #     if definitions:  # If already collected some text, break, assuming section end
                #         break
                if debug:
                    print(f'DDDDD1 {ptext[:5]!r}\n --- {in_definitions_digit!r}')
                if ptext[0].isdigit() or ptext[1] == '.':
                    digit = ptext[0]
                    if not in_definitions_digit:
                        in_definitions_digit = digit
                    else:
                        if digit != in_definitions_digit:
                            # print('?????', digit, '!=', in_definitions_digit, '?????')
                            stop = True
                            break

                while ptext and (ptext[0].isdigit() or ptext[0] == '.' or ptext[1] == '.'):
                    ptext = ptext[1:]
                    ptext = ptext.strip()
                if not ptext:
                    continue

                definition = ptext[2:50]
                delimiter = None
                for delimiter in ['-', ':', '–']:
                    if delimiter in definition:
                        definition = ptext.split(delimiter, 1)
                        definition = [x.strip() for x in definition]
                        definitions.append(definition)
                        in_definitions_errors = 0
                        break
                else:
                    if definitions:
                        definitions[-1][1] += ' ' + ptext
                        in_definitions_errors += 1
                        if in_definitions_errors > 2:
                            print(f'ERROR: too many errors in definitions\n({ptext})')
                            in_definitions = False
                            in_definitions_digit = None
                            in_definitions_errors = 0
                    else:
                        print(f'ERROR: no delimiter found in {definition!r}\n({ptext})')
                        in_definitions = False
                        in_definitions_digit = None
                        in_definitions_errors = 0
                
                # print(f'>>>>({paragraph.style.name}): {ptext}<<<<')
                        
    return definitions

# %%
def get_document_contents(service, file_id):
    request = service.files().get_media(fileId=file_id)
    fh = io.BytesIO()
    downloader = MediaIoBaseDownload(fh, request)
    done = False
    while done is False:
        status, done = downloader.next_chunk()
    fh.seek(0)
    doc = Document(fh)
    return doc

def find_definitions_section(document):
    definitions = []
    in_definitions = False
    in_definitions_digit = None
    for paragraph in document.paragraphs:
        ptext = paragraph.text.strip()
        if not ptext:
            continue
        ptextline = ptext.split('\n')[0][:15]
        if ptextline.replace(':', '').endswith('הגדרות'):
            in_definitions = True
            if ptext[0].isdigit():
                in_definitions_digit = ptext[0]
            # print('!!!!!', ptext, '!!!!!')
            continue
        
        assert 'הגדרות' not in ptextline, f'ERROR: spurious definitions {ptext}, {repr(ptextline)}'
        if in_definitions:
            if paragraph.style.name.startswith('Heading') or paragraph.style.name == 'List Paragraph':
                if text:  # Assume section end if another heading is encountered
                    break
            if ptext[0].isdigit():
                digit = ptext[0]
                if not in_definitions_digit:
                    in_definitions_digit = digit
                else:
                    if digit != in_definitions_digit:
                        # print('?????', digit, '!=', in_definitions_digit, '?????')
                        break

            while ptext and (ptext[0].isdigit() or ptext[0] == '.'):
                ptext = ptext[1:]
                ptext = ptext.strip()
            if not ptext:
                continue

            definition = ptext[:50]
            delimiter = None
            for delimiter in ['-', ':', '–']:
                if delimiter in definition:
                    break
            else:
                print(f'ERROR: no delimiter found in {definition!r}\n({paragraph.style.name}, {ptext})')
                break
            definition = ptext.split(delimiter, 1)
            definition = [x.strip() for x in definition]
            definitions.append(definition)
            # print(f'>>>>({paragraph.style.name}): {ptext}<<<<')
    return definitions

# %%
import time
docs_service = build('docs', 'v1', credentials=creds)

collected = []
print(len(docs))
for i, doc in enumerate(docs):
    # if doc['legacy'] is False:
    # if doc['id'] != '174rpFY7OVvNqyr7vmFwG16WBjDUzL_uQhAxBpX4V5dQ': continue
    print(f"{i:03d}:Document: {doc['name']} - {doc['link']}")
    for retry in range(3):
        try:
            text = get_document_contents(docs_service, doc['id'])
            definitions = find_definitions_section(text)#, doc['id'] == '1TzyUHUbdj9MYeufkBZI4YbLLxZhHnwLuVfKvPpLxCFc')
            for definition in definitions:
                collected.append((doc['name'], doc['path'], definition[0], definition[1]))
                print(f" - {definition[0]}::")
                print(f"   {definition[1]}")
            break
        except TimeoutError as e:
            print(f'RETRYING... {retry+1}/3')
            time.sleep(60)
            continue

        except Exception as e:
            # raise
            # clsname = e.__class__.__name__
            # if clsname in ('sasad'):#'ValueError', 'BadZipFile'):
            #     pass
            print(f'{i:03d}:ERROR: {doc['name']} :', e.__class__.__name__, e)
            print(f'  - {doc['link']}')
    time.sleep(1)


with open('definitions.pickle', 'wb') as f:
    pickle.dump(collected, f)

with open('definitions.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerow(['Document', 'Path', 'Term', 'Definition'])
    for row in collected:
        writer.writerow(row)
# Out:
# 679
# 000:Document: תוכנית יחדיו - https://docs.google.com/document/d/147gGBT6cciuKPYgiBf5SWvkmO_msT8JXkPWXVulEiiY/edit?usp=drivesdk
# 001:Document: מרכזיאיבחוןמסוגלות - https://docs.google.com/document/d/18XQFQ6ZCTgeKYLqnvLncm05oDDiTIdteTi8D7b83-DA/edit?usp=drivesdk
# 002:Document: טיפולישיניים - https://docs.google.com/document/d/1zoFQhq7Ke4gd0-hMpTdMobDTO9zR-5h0kkIxCMnkRNU/edit?usp=drivesdk
#  - הפוליסה::
#    הסכם על כל התנאים והתנאים הכלולים עפ"י מכרז – ביטוח שיניים והנספחים המצורפים אליו.
#  - בעל הפוליסה::
#    משרד העבודה והרווחה.
#  - פנימיה::
#    מוסד ילדים, משפחה אומנת, הוסטל או כל מסגרת אשר בה נמצאים חניכים כולל לינה שהופנו ע"י משרד העבודה והרווחה או ע"י שירותי הרווחה של הרשות המקומית או חניכים בפנימיות אשר משרד העבודה והרווחה משתתף במימון אחזקתם.
#  - רופא מוסכם::
# 035:Document: נוהל משותף בין השרות להתמכרויות לבנינו 11 05 - https://docs.google.com/document/d/1M7635FLw8BmkQMP93UIhKmEM_RDuDXtIalOXPstXQbU/edit?usp=drivesdk
# 036:Document: המלצה על הארכת גמלת הבטחת הכנסה באישור מפקח מחוזי - https://docs.google.com/document/d/1T1pbdtWwgaEmlunOZvROdP-Q2p2kmryohGUyV66d7eU/edit?usp=drivesdk
# 037:Document: טופס סכום נסיבות עזיבה - https://docs.google.com/document/d/1fTVORbacJzgnlOLIbOdbQ4mOfbzOOK2MgxJr0E_xjLc/edit?usp=drivesdk
# 038:Document: שאלון אינטייק לנפגעי התמכרויות (5) - https://docs.google.com/document/d/15T50kUyh0vqhjCnMTbLLesm9sTq1b2Riq0ovvBtD0bs/edit?usp=drivesdk
# 039:Document: סכום תלת חודשי - https://docs.google.com/document/d/1rEzqguKQVbma_on4CcZBYwLsW7eqmVageUN3N6dR07U/edit?usp=drivesdk
# 040:Document: טיפול בילדים נפגעי עברות מין - https://docs.google.com/document/d/1k5HuOyDfqJDTLJdAXhCSYHVa1EUw1gKc5JKwqlNyBHA/edit?usp=drivesdk
# 041:Document: תקנות עובדים סוציאליים - https://docs.google.com/document/d/1aI3zBQV7-Q_Zq06L8tc1u3yBmCMyau_0TglIoDuHkHI/edit?usp=drivesdk
# 042:Document: נוהל עבודה חבצלת פיגועים - https://docs.google.com/document/d/11wy-IFOJKM42NNNm2rN4jIaN32_Gc7drp9W6Z1aGJ9w/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (*פגיעה מנשק שהיה מיועד לפעולות איבה של כוחות אויב, או פגיעה מנשק שהיה מיועד נגד פעולה כזאת, חוץ מפגיעה שנפגע בה אדם בן 18 ומעלה בזמן שהוא עושה מעשה פשע או עובר עבירה שיש בה זדון או רשלנות פושעת.)
#  - "חבצלת פיגועים"::
#    שם קוד לפעילות הכרוכה בהבאה לקבורה של חלל שנהרג בארץ או בחו"ל כתוצאה מפיגוע חבלני/פעולת איבה.
#  - המוסד לביטוח לאומי::
#    האחראי מטעם המוסד לביטוח לאומי על קיום נוהל זה הוא ראש אגף נפגעי פעולות איבה וראש אגף השיקום.
#  - משרד הפנים::
#    הוא הגוף האחראי על תיאום וביצוע נוהל "חבצלת פיגועים" בין הגופים והמשרדים השונים, באמצעות הרשות המקומית אשר בתחומה אירע הפיגוע החבלני/פעולת איבה.
#  - הממונה::
#    מי שמונה על-ידי משרד הפנים כאחראי על ביצוע נוהל זה.
#  - הרשות המקומית::
#    ההתייחסות אל הרשות המקומית הנה על פי העניין:
#  - רשות מקומית – כל הרשויות המקומיות::
#    עיריות, מועצות מקומיות או מועצות אזוריות. המחויבות לביצוע נוהל "חבצלת פיגועים".
#  - רשות מקומית אשר בתחומה אירע הפיגוע החבלני::
#    הרשות אשר בתחומה אירע הפיגוע הנה האחראית עד לזיהוי החלל. עם הזיהוי תפנה לרשות בה התגורר החלל, תעדכן ותסייע לה. רשות מקומית אשר בה התגורר החלל ושבתחומה מובא החלל לקבורה - האחריות לביצוע נוהל "חבצלת פיגועים" מוטלת על הרשות המקומית בה התגורר החלל. כאשר הפיגוע לא אירע בתחומה של הרשות המקומית בה התגורר החלל, תתעדכן רשות זו מהרשות המקומית בה אירע הפיגוע ותכנס לפעולה באופן מיידי. הרשות המקומית בה אירע הפיגוע תסייע לרשות המקומית בה התגורר החלל.
#  - פיגוע חבלני /פעולת איבה::
#    הנם אחד מאלה: *פגיעה מפעולות איבה של כוחות אויב, לרבות פעולות איבה שאירעו מחוץ לישראל ומטרתן הייתה פגיעה בעם היהודי. *פגיעה בשגגה מידי אדם עקב פעולות איבה של כוחות אויב, או פגיעה בשגגה בנסיבות שהיה בהן מקום לחשש סביר שתבוצע פעולת איבה. *פגיעה מנשק שהיה מיועד לפעולות איבה של כוחות אויב, או פגיעה מנשק שהיה מיועד נגד פעולה כזאת, חוץ מפגיעה שנפגע בה אדם בן 18 ומעלה בזמן שהוא עושה מעשה פשע או עובר עבירה שיש בה זדון או רשלנות פושעת.
# 043:Document: תפיסת הפעלה בחירום - https://docs.google.com/document/d/1FqeYgkGUFgZ8GGbc1AfdqMoTTxE5dFGw73kqeK4mciI/edit?usp=drivesdk
# 044:Document: משעול - https://docs.google.com/document/d/1u0Jmqk2eFef04xIZ43b9nFXJsVh71EPV_2jd9uIxiaA/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (אוכלוסיות במתחמים שכונתיים המשלבים עולים וותיקים, תוך דגש על ריכוז גבוה של משפחות עולים. ייחודה של התוכנית הינו העבודה במתחם ספיציפי, תוך הגשמת הרעיון של העצמה ממוקדת והתייחסות כוללנית ומקיפה למגוון הבעיות והקשיים העולים מן המתחם.)
#  - מתחם משעו"ל::
#    אזור ההתערבות הנבחר. מתחם משעו"ל הינו מתחם רציף של בנייני מגורים, כאשר לו שני מאפיינים מרכזיים: ריכוז גבוה של עולים חדשים ותשתית פיזית רעועה ולא מתוחזקת. מספר המשפחות הממוצע במתחם משעו"ל הינו 350 ומספר הבניינים הממוצע הוא 4.
#  - סביבת מגורים::
#    הסביבה הכוללת של הדירה הפרטית. סביבת המגורים כוללת את הכניסה המשותפת ויוצאת החוצה לכיוון השטחים הציבוריים הפתוחים, שביל הגישה לבניין ומתחם האשפה. סביבת המגורים אינה כוללת רק את הדירה הפרטית.
#  - תושב מוביל שינוי::
#    דייר במתחם משעו"ל, אשר במסגרת פעילותו במתחם בתוכנית משעו"ל נכון לקבל על עצמו אחריות והינו שותף בעשייה במתחם, החל מרמת התיכנון והחשיבה ועד לשלב הביצוע והשימור. חלק אינטגרלי מצוות משעו"ל במחתם.
#  - שינוי::
#    שיפור איכות החיים במתחם, הן במובן הפיזי (תשתית וחזות) והן במובן המשפחתי- חברתי- קהילתי.
#  - שיפוץ מוגבל::
#    שיפוץ פיזי בהיקף של עד 50.000 ₪. השיפוץ הינו שיפוץ חזותי- קוסמטי ואינו כולל החלפת או תיקון תשתית. בשיפוץ זה משתתפים הדיירים בעלויות באופן יחסי.
#  - שיפוץ מלא::
#    שיפוץ בהיקף הגבוב מ- 50.000 ₪. השיפוץ כולל גם החלפת או תיקון תשתיות הבניין ואינו מוגבל רק להיבט הקוסמטי. שיפוץ שכזה ילווה בפיקוח הנדסי מלא ורציף מטעם התוכנית. שיפוץ מלא הינו תוצר של שיתופי פעולה בין גורמים שונים בישוב והדיירים משתתפים בעלויות באופן יחסי.
#  - וועדת היגוי ארצית::
#    וועדה המורכבת מנציגי מסד קליטה ומגורמים מקצועיים שונים. הוועדה פועלת כמלווה מקצועית וכבסיס לחשיבה משותפת והמשכיות התוכנית. הוועדה שוקדת על פיתוח מודלים חדשים והפעלתם. הוועדה מתכנסת אחת לשנה, בהנחייתה של המנהלת הארצית.
#  - וועדת היגוי ישובית::
#    פועלת במקביל לוועדת ההיגוי הארצית ומורכבת מגורמי מקצוע תוך ישוביים. הוועדה מתכנסת אחת לשנה בהנחיית רכז משעו"ל היישובי ובוחנת התקדמות ושיתופי פעולה תוך-ישוביים. הוועדה הינה חלק מתהליך ההטמעה היישובי של התוכנית.
#  - וועד בית::
#    הגוף המארגן את ההתנהלות השוטפת של בניין המגורים המשותף. התנהלות זו כוללת תחזוקה שוטפת, פתרון בעיות נקודתיות, נקיון ושמירה על סעיפי החוק הרלוונטיים לקיום בניין מגורים משותף. וועד הבית מורכב מנציגי דיירים ומקיים חשבון בנק שוטף. וועד הבית בתוכנית משעו"ל הינו התוצר הסופי והמתבקש של העבודה סביב הנושא הפיזי בבלוק. מצב חירום, בית משעול, פורום תושבים. אוכלוסיית יעד אוכלוסיות במתחמים שכונתיים המשלבים עולים וותיקים, תוך דגש על ריכוז גבוה של משפחות עולים. ייחודה של התוכנית הינו העבודה במתחם ספיציפי, תוך הגשמת הרעיון של העצמה ממוקדת והתייחסות כוללנית ומקיפה למגוון הבעיות והקשיים העולים מן המתחם.
# 045:Document: נספח א כללי התנהגות במקלט - https://docs.google.com/document/d/1CDcpD4nCbbMfpqodgOWIqPSKCxevrvwaqzFaOm2qk20/edit?usp=drivesdk
# 046:Document: ילדיםיתומים - https://docs.google.com/document/d/1ov62jWqEFHo_I89oWo7NlmwvYuP5ul3sYdyxrES8zxU/edit?usp=drivesdk
# 047:Document: נספחים למקלט לנשים מוכות - https://docs.google.com/document/d/1FSYRRXSlNF3QRoLAjOjtXrrpubVq6DvVfpDsT1ds9Lg/edit?usp=drivesdk
# 048:Document: נספחי יג מקלט נשים מוכות - https://docs.google.com/document/d/1Z77rPUcpvQRHWtR2mK9NZ_aHCLsN7Sd7kb7iz6qS700/edit?usp=drivesdk
# 049:Document: נספח יד מקלט נשים מוכות - https://docs.google.com/document/d/1Yf054xz-3HocbwqEgDbXclUi7DTBUTAJrQ4_gqZhxBc/edit?usp=drivesdk
# 050:Document: דוחמסכםתשומותעוסמרחבי - https://docs.google.com/document/d/149nRr6LzR-XYaSEBs9ji9koAldBRf7qLvBccNptyCkg/edit?usp=drivesdk
# 051:Document: סקרתכנוןמבניםלמחלקה - https://docs.google.com/document/d/1P58Hii9iIYD14sxEqU4afeBp80u7CBwCW5vR0m8nUhM/edit?usp=drivesdk
# 052:Document: צרכי הדרכה מחלקות קטנות - https://docs.google.com/document/d/1kR7NowClBk04PW-SpI2l7ebpedx3NqxxJ-pPmCWO7nY/edit?usp=drivesdk
# 053:Document: תקציר דיווח מסר - https://docs.google.com/document/d/1HZWlsshiMr3F2xEsuASadEhGGzhd8WCPJaAhcHg83Lo/edit?usp=drivesdk
#  - נתוני יסוד::
#    ראה הוראה 1.19 בתע"ס.
# 054:Document: מבנה ארגוני של המחלקה לשח - https://docs.google.com/document/d/1JvI81jedsTVBMWPMXAGa7gYY_e5tQL-bHRGNnUqALDo/edit?usp=drivesdk
# 055:Document: החלמה לנשים אחרי לידה - https://docs.google.com/document/d/1vvRja6jj3yOYzn-dvv4HFzvAitA2lssJZ_Hh-NNSkQ0/edit?usp=drivesdk
# 056:Document: מיזם תוצאות ביעוץ אירגוני - https://docs.google.com/document/d/1E7zpNXNa8LIaJRy2WshmK2-LJsJQ56fON8xyvdercsQ/edit?usp=drivesdk
# 057:Document: תעס חירום  - טיוטא (2) (2) (2) - https://docs.google.com/document/d/1i-eCXjc5UBCI9R4CmLKpW9nCzqlWaE4HKkEHd8VD_T8/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (המעגל השני כולל בתוכו את האוכלוסיות שבתחום ייעודו של המשרד (כל האוכלוסיות שנכללות בנתוני היסוד של המשרד), המתגוררות בקהילה ברשויות המקומיות.)
#  - שעת חירום/מצב מיוחד בעורף::
#    הוא מצב חוקי בישראל, המוכרז בעת שאוכלוסייה אזרחית בעורף מצויה תחת מתקפה ממושכת. ההכרזה מיועדת על מנת להקנות לשלטונות סמכויות שונות שיאפשרו לשמור על הסדר הציבורי ועל שלומם של האזרחים.
#  - שעת חירום (שע"ח)::
#    כינוי למציאות בה יש הכרזה פורמאלית (של הממשלה) על קיום שעת חירום במשק, בדרך כלל בזמן מלחמה. לכך ישנן השלכות נרחבות על התנהלות המשק וכלל פעילות מסגרת החיים האזרחית.
#  - מצב חירום::
#    מצב בו התרחש אירוע אסוני בדרך כלל ברשות מקומית אחת או מספר בודד של רשויות.
#  - מטה חירום רשותי::
#    מורכב מההנהגה של הרשות, הכוללת את ראש הרשות, מנכ"ל, מנהלי המכלולים ומנהלי האגפים ברשות המקומית, מפקד היקל"ר ונציגי ארגוני החרום (משטרה, כיבוי אש, מגן דוד אדום). מטה זה, הוא הגוף האחראי על הפעלת הרשות בזמן אירועי חירום ובשגרת החירום – ועל מתן השירותים החיוניים לתושבים. מטה החירום ממוקם בדרך כלל בחמ"ל רשותי ("מרכז הפעלה" – מרה"פ).
#  - מכלולים::
#    נדבך מרכזי במבנה הארגוני של הרשות המקומית בחירום
#  - בכל רשות ישנם מספר מכלולים קבועים::
#    מכלול מטה מינהלי לוגיסטיקה,הנדסה ותשתיות,מידע והסברה, אוכלוסייה ורווחה ,חינוך. מעגלי ההתייחסות של האוכלוסייה המטופלת.
#  - המעגל הראשון הוא מעגל החוסים בטיפול בסידור חוץ::
# 073:Document: תקנותשירותיהסעדתשמו1986 - https://docs.google.com/document/d/1V4KiTeOPkXddJ5mQF3sOA6fKVyFWsvncXLjcsA8LlkE/edit?usp=drivesdk
# 074:Document: מסמך ייזום מערכת אל-אלימות - https://docs.google.com/document/d/19YOQM6b0QGh7XIKMdoIjtF99_IaCsGgGToshfRQGg_A/edit?usp=drivesdk
# 075:Document: מרכז הסעות - https://docs.google.com/document/d/1Pb35DXUDK-9tbFEt2jdTUM1Uu9qzFe0-1M-IaEXpt70/edit?usp=drivesdk
# 076:Document: נוהלדיווחבמקריאורותאדומים - https://docs.google.com/document/d/10La0nv77bmXqfswCNkWcShIcrDJUKhcN8-GU7BTE7L4/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (משטרה, פסיכיאטר מחוזי וכדומה.)
#  - אירוע "אורות אדומים"::
#    מקרה בהם העו"ס, על פי המידע העומד לרשותו, מעריך כי קיימת או עלולה להתקיים, סכנה ממשית לחייו של אדם כלפי עצמו ו/או כלפי בן משפחתו ו/או כלפי אדם אחר.
#  - אירוע בו מתקיימים אחד או יותר מהמצבים הבאים::
#     אירוע שאין לו פתרון במסגרת המענים הקיימים. אירוע, שלשם מניעתו, יש צורך במעורבות או בהתערבות של מערכות נוספות, כגון: משטרה, פסיכיאטר מחוזי וכדומה.
# 077:Document: נוהל הפנייה לביצוע חקירה - https://docs.google.com/document/d/1X2t1YCCMfREseL-HwfaP-unKVnjq3dw6uPP4lhLo5ns/edit?usp=drivesdk
# 078:Document: אלכוהול - פניה וקבלה לטיפול במסגרות אמבולטוריות - https://docs.google.com/document/d/1vWrglvoSgg6qqECW8HfwoZZiCmIWOE3jjZxXAY6-9oE/edit?usp=drivesdk
# 079:Document: הטיפולבאסיריםמשוחררים - https://docs.google.com/document/d/1CU7B-QuSrcfrdgelp1JwwwtE5qJ2B2aDMrfBfXzblGM/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (-30.)
#  - אסיר משוחרר::
#    כמשמעו בחוק הרשות לשיקום האסיר, התשמ"ג-1983. אסיר משוחרר אזרח ישראל, שפנה לרשות בתוך שנה מיום שחרורו. יובהר כי בנוהל זה, אסיר משוחרר ברישיון ("שליש"), דינו כדין אסיר משוחרר אשר סיים לרצות את מלוא מאסרו.
#  - הרשות לשיקום האסיר::
#    כמשמעה בחוק הרשות לשיקום האסיר, התשמ"ג-1983. תפקידי הרשות הם : גיבוש מדיניות שיקום לאסירים, ובכלל זה מדיניות שיקום לאוכלוסיות אסירים מיוחדות ; הכנת תכניות שיקום לאסירים לקראת שחרורם בתיאום עם שב"ס, והפעלתן לאחר שחרורם ; קליטת אסירים ושיקומם בקהילה, לרבות בתחומי התעסוקה, הכשרה מקצועית, הבטחת הכנסה, דיור ושירותי בריאות ; ייזום, הקמה ופיתוח של שירותי עזר לשיקום האסיר, לרבות שירותי הכוונה וייעוץ ; סיוע למשפחות האסירים בעת המאסר ואחריו באמצעות לשכות הרווחה המקומיות וגופים אחרים ; תיאום בין משרדי הממשלה, הרשויות המקומיות והחברה האזרחית בנושאים הקשורים בשיקום האסיר ; עידוד פעילות התנדבותית בקרב יחידים וגופים בתחום שיקום האסיר, הדרכתם והנחייתם ; פיקוח על גופים מתנדבים העוסקים בשיקום האסיר וקביעת כללים להקצבות מתקציב הרשות לגופים אלה ; ייזום הצעות חקיקה ומחקרים לקידום ופיתוח נושא שיקום האסיר בישראל ; פעילות להגברת המודעות הציבורית לנושא שיקום האסיר.
#  - יועץ כלא::
#    קהילה ברשות לשיקום האסיר – עובד סוציאלי ברשות לשיקום האסיר, או עובד עם הכשרה אחרת שהוכר על-ידי מנכ"ל הרשות לשיקום האסיר, אשר תפקידו מחד לאבחן ולהפנות אסירים מתאימים לתכניות שיקום לקראת שחרורם, ומאידך לפקח וללוות את תכנית השיקום לאחר שחרורו של האסיר מבית הכלא. יועץ הרשות לשיקום האסיר בקהילה - אחראי על ייעוץ, פיקוח ובקרה על פעילות שיקום אסירים המתבצעת בישובים שבאחריותו. היועץ אחראי על פעילות רכזי שיקום האסיר, ובכלל זה על בניית תכניות שיקום לאסירים ועל הפעלתן. יועץ שיקום האסיר מדריך ומנחה את רכז שיקום האסיר. הנחייה זו, אפשר שתבוא בנוסף להנחיה אותה יתכן ומקבל הרכז במחלקה בה עובד.
#  - עו"ס שיקום האסיר::
#    עובד סוציאלי במחלקה לשירותים חברתיים, האחראי על הטיפול באסירים משוחררים תושבי עירו, בין הפונים מיוזמתם ובין המופנים מבתי הכלא, וכן אחראי על הטיפול בבני משפחות האסירים (לפירוט תפקידיו של רכז עו"ס שיקום האסיר, ראה נספח מס' 2 – רכז הרשות לשיקום האסיר בקהילה : הגדרת תפקיד ודרכי עבודה נספח 2.
#  - דרגתו תהיה רמה י'::
#    ח'.
#  - כפיפות::
#    רכז עו"ס שיקום האסיר ברשות המקומית יהיה בכפיפות ישירה למנהל מחלקת מחלקה לשירותים חברתיים.הרווחה או אגף הרווחה בהתאמה למבנה הארגוני.
#  - ועדה להכנת תכניות שיקום – כהגדרתה בנוהלי שב"ס::
#    הרשות לשיקום האסיר ובתקנות הרשות לשיקום האסיר. ועדת אבחון בראשותו של יועץ הרשות לשיקום האסיר ובהשתתפות עו"ס בית הכלא. הועדה מתקיימת בעניינם של כל האסירים השפוטים לתקופה שמעל לחצי שנה, ומטרתה גיבוש המלצה והחלטה באשר להמשך הטיפול באסיר לקראת מועד שחרורו המוקדם או המלא מבית הכלא. אוכלוסיית היעד אוכלוסיית האסירים הנה הטרוגנית, וחוצה מגזרים ושכבות באוכלוסייה. באופן כללי ניתן לומר כי אחוז ניכר מקרב אוכלוסיית האסירים סובל מבעיות התמכרות או שימוש לרעה בסמים או אלכוהול, וכן ניכרים שיעורים גבוהים יחסית לאוכלוסייה הכללית של תחלואה נפשית. טווח הגילאים של האוכלוסייה הנו בין 14 (גיל הכניסה המינימאלי לבית כלא) ועד בכלל, כאשר מרבית האסירים הנם בין הגילאים -30.
# 080:Document: מתןשירותייעוץארגוןוניהולפעולותהמועצהלעבודהסוציאלית - https://docs.google.com/document/d/19Q_hhpIstvvnwxCDcwHvJt12aI--l3gRq8Dbw8LeVlI/edit?usp=drivesdk
#  - אסיר משוחרר ברישיון ("שליש")::
#    אסיר אשר נשא לפחות שני שלישים מתקופת מאסרו, ובלבד שנשפט לתקופת מאסר של למעלה מחצי שנה. וועדת השחרורים החליטה לשחררו עפי תנאים או ללא תנאים. ועדת השחרורים קובעת את תנאי שחרורו של האסיר, ורשאית אף לבטלו בגין הפרת תנאי השחרור. לשם גיבוש החלטתה, מקבלת ועדת השחרורים לידיה חוות-דעת של הרשות לשיקום האסיר, לעניין אפשרות שיקומו של האסיר לאחר שחרורו.
#  - הרשות לשיקום האסיר::
#    כמשמעה בחוק הרשות לשיקום האסיר, התשמ"ג-1983. תפקידי הרשות הם : גיבוש מדיניות שיקום לאסירים, ובכלל זה מדיניות שיקום לאוכלוסיות אסירים מיוחדות ; הכנת תכניות שיקום לאסירים לקראת שחרורם בתיאום עם שב"ס, והפעלתן לאחר שחרורם ; קליטת אסירים ושיקומם בקהילה, לרבות בתחומי התעסוקה, הכשרה מקצועית, הבטחת הכנסה, דיור ושירותי בריאות ; ייזום, הקמה ופיתוח של שירותי עזר לשיקום האסיר, לרבות שירותי הכוונה וייעוץ ; סיוע למשפחות האסירים בעת המאסר ואחריו באמצעות לשכות הרווחה המקומיות וגופים אחרים ; תיאום בין משרדי הממשלה, הרשויות המקומיות והחברה האזרחית בנושאים הקשורים בשיקום האסיר ; עידוד פעילות התנדבותית בקרב יחידים וגופים בתחום שיקום האסיר, הדרכתם והנחייתם ; פיקוח על גופים מתנדבים העוסקים בשיקום האסיר וקביעת כללים להקצבות מתקציב הרשות לגופים אלה ; ייזום הצעות חקיקה ומחקרים לקידום ופיתוח נושא שיקום האסיר בישראל ; פעילות להגברת המודעות הציבורית לנושא שיקום האסיר.
#  - נציג רש"א בבית הכלא::
#    עובד סוציאלי של הברשות לשיקום אסיר- עובד סוציאל, או עובד בעל הכשרה אחרת שהוכר ע"י מנכ"ל הרשות לשיקום האסיר, אשר תפקידו לאבחן ולהפנות אסירים מתאימים לתכניות שיקום לקראת שחרורם, ולגבש חוות-דעת המוגשות לוועדות השחרורים, באשר לכלל האסירים הנדונים בוועדות אלה.
#  - מפקח אזורי של רש"א בקהילה::
#    אחראי על פיקוח, בקרה וליווי פעילות השיקום המתבצעת בקהילה. בכלל זה, אחראי המפקח על פעילות עו"ס שיקום האסיר בישובים השונים, על בניית תכניות שיקום ועל הפעלתן לאחר שחרור האסירים מבתי הכלא. המפקח מדריך ומנחה מקצועית את עו"ס שיקום האסיר שבמחלקות לשירותים חברתיים. הנחייה זו תתבצע בתיאום עם מדריך/ ראש צוות במחלקות לשירותים חברתיים.
#  - עו"ס שיקום האסיר::
#    עובד סוציאלי במחלקה לשירותים חברתיים, האחראי על הטיפול באסירים משוחררים ואסירים משוחררים ברישיון תושבי עירו, בין הפונים מיוזמתם ובין המופנים מהרשות לשיקום האסיר, וכן אחראי על הטיפול בבני משפחות האסירים.
#  - דרגתו תהיה י::
#    ח' בדירוג העובדים הסוציאליים.
#  - כפיפות::
#    עו"ס שיקום האסיר ברשות המקומית יהיה בכפיפות ישירה למנהל מחלקה לשירותים חברתיים ו/או למי מטעמו, ובכפיפות מקצועית למפקח אזורי של הרשות לשיקום האסיר.
#  - רכז שיקום אזורי של רש"א::
#    עובד סוציאלי האחראי ליישום תכנית השיקום לאסירים ברשויות קטנות בהן מספר האסירים קטן ביותר. עבודתו תשתרע על פני מספר רשויות בהתאם לקביעת מנהל המחוז ברשות לשיקום האסיר. מנהל המחוז של רש"א יהיה אחראי לתאם את עבודתו ברשות עם ראש הרשות המקומית, ולעגן את ההבנות בהסכם מפורט. הרכז יהיה בכפיפות מלאה לרשות לשיקום האסיר.
#  - ועדה להכנת תכניות שיקום – כהגדרתה בנוהלי שב"ס::
#    הרשות לשיקום האסיר ובתקנות הרשות לשיקום האסיר. ועדה בראשותו שלהרכב הוועדה: נציג הרשות לשיקום האסיר - י"רובהשתתפות ועו"ס בית הכלא. הועדה מתקיימת בעניינם של כל האסירים השפוטים לתקופה שמעל לחצי שנה, ומטרתה גיבוש המלצה והחלטה באשר להמשך הטיפול באסיר לקראת מועד שחרורו המוקדם או המלא מבית הכלא. אוכלוסיית היעד לא ברור מתוך הכתוב מטה מי הם אוכלוסיית היעד? האם כל האסירים המשוחררים? אוכלוסיית האסירים הנה הטרוגנית, וחוצה מגזרים ושכבות באוכלוסייה. באופן כללי ניתן לומר כי אחוז ניכר מקרב אוכלוסיית האסירים סובל מבעיות התמכרות או שימוש לרעה בסמים או אלכוהול, וכן ניכרים שיעורים גבוהים יחסית לאוכלוסייה הכללית של תחלואה נפשית. טווח הגילאים של האוכלוסייה הנו בין 14 (גיל הכניסה המינימאלי לבית כלא) ועד בכלל, כאשר מרבית האסירים הנם בין הגילאים 20-30.
# 091:Document: נוהל שותפות טיוטא מתאריך 7 בספטמבר 2014 - https://docs.google.com/document/d/1vDEmmbg6d90glkXP3RSB7ujxCi9uTTsntPS1_-WaWJg/edit?usp=drivesdk
# 092:Document: תהליך קבלת החלטה באדם עם פיגור - https://docs.google.com/document/d/1MxD1iQFRGynmMiWjZUJ4qXu9WLFkIBVeNqroUJeyaVM/edit?usp=drivesdk
#  - מפגר::
#    הגדרתו בחוק הסעד (טיפול במפגרים) התשכ"ט – 1969.
#  - אחראי על המפגר::
#    הורה, הורה חורג, אפוטרופוס או מי שהמפגר נמצא במשמורתו או בהשגחתו.
#  - ועדת אבחון::
#    גוף המוסמך עפ"י חוק הסעד (טיפול במפגרים) תשכ"ט – 1969 להחליט האם קיים פיגור שכלי. ועדה שמונתה ע"י שר הרווחה והשירותים החברתיים ותפקידה להחליט האם האדם הוא עם פיגור שכלי ואם כן תחליט גם על דרכי טיפול.
#  - מערכת האבחון::
#    מערכת האחראית על מתן שירותי אבחון מקיפים ואוניברסאליים לצורך בדיקת רמת תפקוד וקיום/אי קיום מוגבלות שכלית התפתחותית ( פיגור שכלי).
#  - מרכז אבחון::
#    מסגרת רב מקצועית שזכתה במכרז של משרד הרווחה והשירותים החברתיים לאספקת שרותי אבחון, לצורך בדיקת קיום מוגבלות שכלית התפתחותית (פיגור שכלי) ומהווה חלק ממערכת האבחון .
# 093:Document: מעטפת רכה נוסח טיוטה למיני תעס אוגוסט 2015 - https://docs.google.com/document/d/1Cnyfy2cT9cwJJ7mHoaVtqO87q4bNPIE02zrV7VIYEr4/edit?usp=drivesdk
# 094:Document: מעטפת רכה - https://docs.google.com/document/d/1Ow6X97UecsQ6SauLvZ24f8YA9lLDA8HpjrRTAWkFWbI/edit?usp=drivesdk
# 095:Document: נוהלרווחהמשטרה - https://docs.google.com/document/d/12IauI8v7xXSnq4YdP6295N2oor41F9lUT_vvnpyWqBg/edit?usp=drivesdk
# ERROR: Found "הגדרות" in '1) החלטות למענה ביחס לסיכון הנשקף, יכולות להיות מתוך מגוון המענים בהם נעשה שימוש גם כיום במשטרה כגון – ביקורי ניידות, ביקור רכז מודיעין או מש"ק, קיום קשר טלפוני, הכנסת הגדרות במרכז השלטון המקומי אשר יתנו עדיפות ודחיפות לשיחה מטלפון מסוים, מאזור מסוים או ממקום מסוים אמצעים טכנולוגיים כגון לחצן מצוקה, ועוד..'
# 096:Document: חוברתאלימותכלפיעובדירווחה - https://docs.google.com/document/d/1sJQmNMy2nyJpSAuO2igBlRvhCbMpoUteFCg24kV-Cj0/edit?usp=drivesdk
# ERROR: Found "הגדרות" in 'קיימות מספר הגדרות להתנהגות אלימה, עם זאת, בהתייחס לאלימות במחלקות לשירותים חברתיים ההגדרה שאלימות הינה כל התנהגות הפוגעת, מאיימת, משפילה או מזלזלת באחר, הינה המדויקת ביותר.'
# 097:Document: הדרכה קנויה ייעודית במחלקות - https://docs.google.com/document/d/1nm7hVipsluVpf7xkQHY-nCvms1AIGxdaVgJzFOzml2U/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (מדריכים ראשי צוותים)
#  - הדרכה ייעודית::
#
#  - ועדה מקצועית לאישור ההדרכה::
#
#  - ועדה מקצועית לערעורים::
#     אוכלוסיית היעד מנהלי מחלקות לשירותים חברתיים חדשים מדריכים ראשי צוותים
# 098:Document: חוברתהדרכהמניעהוהתמודדותעםאלימות - https://docs.google.com/document/d/1LTo19DJKMGq3tne3s99U_8gOs1--unr46YAd9meAc6M/edit?usp=drivesdk
# ERROR: Found "הגדרות" in 'קיימות מספר הגדרות להתנהגות אלימה, עם זאת, בהתייחס לאלימות במחלקות לשירותים חברתיים ההגדרה שאלימות הינה כל התנהגות הפוגעת, מאיימת, משפילה או מזלזלת באחר, הינה המדויקת ביותר.'
# 099:Document: תעס וועדות תכנון טיפול והערכה - https://docs.google.com/document/d/1FR0iBgHsJXLTR-1xQUuVGQIMUTNguGAPsiPAj6fkdPs/edit?usp=drivesdk
# 099:ERROR: תעס וועדות תכנון טיפול והערכה : HttpError <HttpError 503 when requesting https://docs.googleapis.com/v1/documents/1FR0iBgHsJXLTR-1xQUuVGQIMUTNguGAPsiPAj6fkdPs?alt=json returned "The service is currently unavailable.". Details: "The service is currently unavailable.">
#   - https://docs.google.com/document/d/1FR0iBgHsJXLTR-1xQUuVGQIMUTNguGAPsiPAj6fkdPs/edit?usp=drivesdk
#  - הוועדה::
#     הגדרה של הוועדה בתקנות הפיקוח על המעונות (אחזקת ילדים במעון רגיל), תשכ"ח 1968 שהותקנו מכח חוק הפיקוח על המעונות תשכ"ה 1965, (נספח א') וכן בחוק פעוטות בסיכון (הזכות למען יום) התש"ס-2000. (נספח 1)ב') "וועדה שליד המחלקה לשירותים חברתיים ברשות המקומית שבתחומה מקום מגוריו של האחראי על קטין, שמתפקידה להחליט על דרכי הטיפול בילד, ושבראשה מנהל המחלקה לשירותים חברתייים של הרשות המקומית או עו"ס שהוא מינה..." או שמציינים את כל ההגדרה או שמפנים לתקנות הפיקוח על המעונות.
#  - בוועדה משתתפים::
#    ההורים, הילד בהתאם לגילו והתפתחותו, צוות בין שירותי ורב מקצועי, אפוטרופוס / אפוטרופוס לדין אם מונה ויש העתק של כתב המינוי. מטרת הוועדה לבחון את הצרכים ולבנות תכנית טיפול מיטבית רב ממדית מותאמת לילד ולמשפחה. מופיע בהגדרת הוועדה.
# 100:Document: הדרכה שיקומית DOC - https://docs.google.com/document/d/1qkf0vcH4hQjBmTw0MRLbSERAIg4_j3Mvn9GWy7vNugw/edit?usp=drivesdk
#  - מורה שיקומי::
#    בעל תעודת הסמכה ישראלית או בעל תעודת הסמכה מגורם רשמי בחו"ל שנבדקה ואושרה עלי ידי השירות לעיוור.
#  - נותן השירות::
#    זכיין גוף שזכה במכרז של משרד הרווחה והשירותים החברתיים לנושא זה.
#  - נותן שירותי תרגום::
#    כמפורט בהוראה 5.7 בתע"ס
#  - מזמין השירות::
#    המחלקה לשירותים חברתיים בהרשות המקומית או ארגון
# 101:Document: מכתב המנכל למנהלי המחוזות תשעו - https://docs.google.com/document/d/14lT-JNQlT8G1KmDuw4EvAAYG63-up92W_B92kZnO8dM/edit?usp=drivesdk
# 102:Document: הנהלים למתן טיפול סוציאלי ו או חומרי- 1.36 - https://docs.google.com/document/d/1392pGkbej2Arf8K8xOJuj4yW9PtS9CXgF8LIcShMqPk/edit?usp=drivesdk
#  - טיפול סוציאלי::
#    כל סוגי העזרה ושירותים סוציאליים למעט סעד.
#  - סעד::
#    עזרה חומרית ישירה או עקיפה שלגביה קיימים כללי 			זכאות.
#  - מקום מגורים::
#    - מקום שבו אוכל אדם וישן, ואם מחמת עבודתו הוא אוכל וישן מחוץ לדירתו אך מבקר בה לעיתים קרובות - דירתו; ואולם אם הוא משרת בצה"ל, או מוחזק במעון או בבית סוהר, לא ייחשב מקום כאמור, בשל כך בלבד, למקום מגוריו; כהגדרתו בתקנות שירותי הסעד (טיפול 			בנזקקים), התשמ"ו - 1986 (ראה הוראה 1.1 בתע"ס). נוהלי הפניה
# 103:Document: 16.1(ב) - https://docs.google.com/document/d/1QYP71gukpYqRG6cccxSnKo5bUd35T7U3gO3LJ2JzxkA/edit?usp=drivesdk
# 104:Document: מסך השתתפות ילדים בסידור האזרח ותיק בבית אבות - למיזוג - https://docs.google.com/document/d/1jyIMsD2Gt2UIjtG63hxWPV27WKIOpG8rlJb6m9lBCOk/edit?usp=drivesdk
edit?usp=drivesdk
# ERROR: too many errors in definitions
# (צמצום ומניעה של הצורך בהוצאה לטיפול במסגרת חוץ ביתית.)
#  - פנימייה– כהגדרתו בחוק הפיקוח על המעונות, התשכ"ה::
#    1965.
#  - פנימיית יום::
#    מסגרת שהייה טיפולית רב תחומית ואינטנסיבית בתוך מבנה הפנימיה האינטרנית המיועדת לילדים בגיל החביון (6-12) והוריהם. פנימיות היום נותנות מענה לרשות אחת או למספר רשויות הממוקמות באותו אזור גאוגרפי. פנימיית יום מופעלת ע"י גוף שזכה במכרז של משרד העבודה הרווחה והשירותים החברתיים להפעלת פנימייה ופנימיית יום.
#  - ועדת תכנון טיפול והערכה::
#    כהגדרתה בהוראה 8.9 בתע"ס, להלן "ועדה".
#  - רפרנט לפנימיית היום מהמחלקה לשירותים חברתיים::
#    מדריך ראש צוות או עובד סוציאלי עם ניסיון בטיפול בילדים ומשפחות בסיכון. אוכלוסיית יעד
#  - ילדים במצבי סיכון בגילאי 6::
#    12 שחלים עליהם הקריטריונים להשמה חוץ ביתית (סעיף 1(ג) ו- 1(ד) וסעיף 2 לתוספת הראשונה, לתקנות הפיקוח על המעונות – אחזקת ילדים במעון רגיל – תשכ"ו, 1965 – ראה נספח א') ובבתיהם יש פגיעה בשלומם ובהתפתחותם התקינה, מסיבות שמקורן בילד, בהורים או ביחסי הגומלין ביניהם (אולם לא נשקפת להם סכנה בחיק משפחתם). פרופיל הילדים המופנים לפנימיית היום מותאם לפנימייה שיקומית (ראה נוהל 0.9, סיווג אוכלוסיות, מסגרות חוץ ביתיות שירות ילד ונוער, נספח ב'). בהתאם לנוהל סיווג זה, ניתן לכלול בפנימיית היום עד 25% מהילדים המתחנכים בחינוך המיוחד – פרופיל טיפולי.
#  - ילדים בגילאי 6::
#    12 ששהו בפנימייה מלאה, להם צורך בהכנה הדרגתית לחזרתם המלאה הביתה.
#  - הורי הילדים (כפי שמוגדרים סעיפים 3.1 ו::
#    3.2) המביעים נכונותם להשתתף בתכנית הטיפול האינטנסיבית שמציעה להם פנימיית היום. זהו קריטריון משמעותי המבחין בין ילדים שיופנו לפנימייה מלאה לעומת ילדים שיופנו לפנימיית היום. קליטת ילדים שלא בטווח גילאים זה תתאפשר במקרים ייחודיים שיבחנו ויאושרו על ידי מפקח הקהילה המחוזי בשרות לילד ולנוער. מטרות צמצום ומניעה של הצורך בהוצאה לטיפול במסגרת חוץ ביתית.
# 121:Document: 16.1 נגיש - https://docs.google.com/document/d/1EMREeI4LE6Ew89SE9wCZa1eFtEnufVaWQbcFdKz5enk/edit?usp=drivesdk
# 122:Document: מיון תיקים 1.21  2017 - https://docs.google.com/document/d/12MjBAbMIEhdH2tVrVvH4IY4bzNG9HicCjd2wJmxGpRU/edit?usp=drivesdk
# 123:Document: 1.43 - https://docs.google.com/document/d/14YO-X_NY_3mHwnZ-226RO1nim0U9sXoD2NedUwWvNOs/edit?usp=drivesdk
# 124:Document: 6.10 נגיש - https://docs.google.com/document/d/10l-Ko3L9FpqxBAyjhWz0UKtTMMuOnOhnw8cPk5hAByQ/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (אוכלוסיית היעד)
#  - ארגון מפעיל::
#    גוף שנבחר במכרז על ידי משרד העבודה, הרווחה והשירותים החברתיים לצורך הפעלת מרכז תעסוקתי מוגן.
#  - משתקם::
#    אדם עם עיוורון/לקות ראייה או נכה המועסק במרכז תעסוקתי בעבודה יצרנית.
#  - תשלום קבוע::
#    שכר בסיס בגובה של לפחות 50% משכר שעת עבודה בחברת "המשקם".
#  - גמול ביצוע עבודה::
#    השכר הנובע מתפוקת המשתקם.
#  - תנאים סוציאליים::
#    התנאים הסוציאליים מהווים 18.33% מהשכר כמפורט בסעיף 10.4 בהוראה זו.
#  - ועדת תעסוקה מקומית::
#    ועדה ברשות המקומית שתפקידה לבחון, לדון ולהחליט עם המועמד על מידת התאמתו להשמה במרכז לתעסוקה מוגנת, השעייתו והפסקת ההשמה. אוכלוסיית היעד
# 125:Document: 5.18 נגיש - https://docs.google.com/document/d/1fkDqxKCL-K1GzJsgD_O37wzgWpWBBeygcj_PBY5Wypo/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (פיתוח מסוגלות תעסוקתית מותאמת לדרישות שוק העבודה.)
#  - נכות גופנית::
#    קשיי תפקוד בתחום המוטורי כתוצאה ממחלה כרונית, קטיעה פגיעת ראש, פגיעת עמוד שדרה וכו'.
#  - נכות חושית::
#    קשיי תפקוד בתחומים מרכזיים כגון: תקשורת, ניידות, וניהול חיי היום יום כתוצאה מחרשות ו/או עיוורון. ו/או עיוורון כל ליקוי בריאותי הגורם לפגיעה בלתי הפיכה שאירעה לאדם מלידה ועד גיל 18.
#  - נכות התפתחותית::
#    כל ליקוי בריאותי הגורם לפגיעה בלתי הפיכה שאירעה לאדם מלידה ועד גיל 18. כתוצאה מפגיעה זו עלולים להופיע קשיי תפקוד בתחום המוטורי, ו/או החושי ו/או החברתי, ו/או הרגשי, ו/או ההתנהגותי.
#  - מפעל מקדם תעסוקה::
#    מסגרת שיקומית הנותנת שירותי תעסוקה שיקום והכשרה, ומופעלת על ידי ארגון מפעיל שזכה במכרז של המשרד או על ידי הרשות המקומית.
#  - גמול ביצוע עבודה::
#    התגמול הכספי יינתן לכל מקבל שירות בגין עבודתו, התשלום נובע מתפוקתו ומתשלום המתקבל עבור מוצרים המיוצרים במפעל.
#  - סובסידיה::
#    זכאות לקבלת תגמול כספי, המהווה השלמת תשלום למקבלי גמול ביצוע עבודה.
#  - העסקה כחוק::
#    המפעל יפעל לקדם העסקה ישירה בתנאי שכר בהתאם לחוק. אוכלוסיית יעד
#  - אנשים בגילאי 18::
#    67 המוכרים על ידי ביטוח לאומי עם נכות מעל 40%, ושיכולת עבודתם אינה תואמת בשלב זה את דרישות העסקה בשוק הפתוח, לרבות תעסוקה נתמכת ועל כן מתאימים למפעל מקדם תעסוקה. אוכלוסיית ותיקים ממשיכים בגיל 67 ומעלה המסוגלים להמשיך לעבוד במפעל מקדם תעסוקה בהתאם להחלטת ההנהלה ובכפוף לתכנית מותאמת. מטרות פיתוח מסוגלות תעסוקתית מותאמת לדרישות שוק העבודה.
# 126:Document: 8.28 נגיש - https://docs.google.com/document/d/1pH-FY8ILbcn-lUbNLHJav4har6xu6jnEPiBk34mYTn4/edit?usp=drivesdk
# 127:Document: 1.34 נגיש - https://docs.google.com/document/d/1HA6TL6a5E9k5qIQwtV4w-3YrfY8EPhtryTolgW3TZKo/edit?usp=drivesdk
# 128:Document: 1.21 נגיש - https://docs.google.com/document/d/1giXYoZ5OrDmKRutJXwSQzTJOF4SGdwTKyoK2CK6yPNw/edit?usp=drivesdk
# 129:Document: 11.7 נגיש - https://docs.google.com/document/d/124o_iPqocOhoKmnI-tP05LkgqGmc1-XwAJ8WLDs0AgA/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (מקרה שני שבו הלקוח הינו חלק מבית אב שבעייתו המרכזית היא התמכרות ויתכן וישנם בעיות נוספות בבית האב.)
#  - עובד סוציאלי משפחה::
#    עובד סוציאלי מנהל ההתערבות במחלקה לשירותים חברתיים.
#  - עובד סוציאלי התמכרויות::
#    כהגדרתו בתקנון העובדים הסוציאליים 2.4 כוח אדם במחלקות.
#  - יחידה להתמכרויות – יחידה לטיפול בהתמכרויות::
#    מסגרת אמבולטורית אשר קיבלה רישיון להפעלה בהתאם ובכפוף לתקנות הפיקוח על מוסדות לטיפול במשתמשים בסמים תשנ"ד – 1994 ומצריכה קבלת רישיון להפעלה. כהגדרתה בתקנון העובדים הסוציאליים 11.1.
#  - התמכרות – התמכרות::
#    תהליך התדרדרות אותו עובר אדם ובו נוצרת תלות בחומר, משנה מצב רוח או התנהגות, עד לפגיעה בחלק ניכר מהתפקודים המרכזיים בחייו. האדם המכור מתקשה להפסיק את התהליך שהינו פיזי רגשי וחברתי וניזקק לסיוע כדי לעזור לו להיגמל מהחומר או מההתנהגות כהגדרתו בתקנון העובדים הסוציאליים 11.1.
#  - תהליך ההתערבות::
#     ניתן להבחין בין שני מקרים מבדילים בהתייחסות של חלוקת האחריות בין עובד סוציאלי התמכרויות לבין עובד סוציאלי משפחה. מקרה אחד שבו הלקוח הינו אדם בודד (ללא משפחה) שבעייתו המרכזית היא ההתמכרות. מקרה שני שבו הלקוח הינו חלק מבית אב שבעייתו המרכזית היא התמכרות ויתכן וישנם בעיות נוספות בבית האב.
# 130:Document: 3.16 (נגיש) - https://docs.google.com/document/d/1ZeM3JEEh54YwI3VbSGxTgNIgXk-zPlF81vsANgDjVMU/edit?usp=drivesdk
# ERROR: no delimiter found in 'דרת משפחה'
# (הגדרת משפחה)
# 131:Document: (15.4.18) נגיש 3.16 - https://docs.google.com/document/d/1BzYlWN-T8p_3OvwroxF4u29-hKFfOBmj4pDMM8n7b2o/edit?usp=drivesdk
# ERROR: no delimiter found in 'דרת משפחה'
# (הגדרת משפחה)
# 132:Document: 3.16 נגיש - https://docs.google.com/document/d/13rGkmfRzpyO-MHWxaC04zVejyhqAMin1KoyaRVS9ukM/edit?usp=drivesdk
# ERROR: no delimiter found in 'דרת משפחה'
# (הגדרת משפחה)
# 133:Document: 1.23 נגיש - https://docs.google.com/document/d/1arvcUCWLHlsmsvlCkknaTZPHWFjUrbbdsDx7guJzVSE/edit?usp=drivesdk
# 134:Document: 6.8 נגיש - https://docs.google.com/document/d/1PlG5VpFGKZf4CrRaYhVGvkDHMQ-V1Cqf9V2rSR_c4G8/edit?usp=drivesdk
# 135:Document: ועדות ערר - עקרונות ונהלי עבודה - 1.8 (נגיש) - https://docs.google.com/document/d/1jpffsD-dnMZtSQ0ymxX17Ji2reXD_npvtA2KapW1i_E/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (המנהל הכללי של המשרד יקבל מאת מנהל המחלקה לוועדות ערר וסיוע לבודדים, הצעות למועמדים ויעבירם לשר הרווחה.)
#  - "המשרד"::
#     משרד העבודה, הרווחה והשירותים החברתיים.
#  - "ועדה"::
#     ועדת ערר אזורית, הפועלת על פי חוק שירותי הסעד תשי"ח 1958, חוק בתי דין מנהליים תשנ"ב – 1992, תקנות שירותי הסעד – סדרי הנוהל בועדות ערר תשכ"ו – 1965.
#  - "ערר"::
#
#  - השגה בכתב המוגשת לוועדה על::
#     החלטת המחלקה לשירותים חברתיים של רשות מקומית לבקשת הלקוח. אי מתן תשובה בכתב לבקשתו של הלקוח "ליתן טיפול סוציאלי או להגיש סעד" על ידי המחלקה לשירותים חברתיים תוך זמן סביר - "זמן סביר" (סעיף 2(ב) לחוק שירותי הסעד) – נקבע כי "זמן סביר" הוא 30 ימים.
#  - "מרכז"::
#     מרכז ועדות ערר מטעם המשרד במחוז.
#  - "מנהל מחלקה"::
#
#  - כאמור::
#    בתקנות שירותי הסעד (סדרי הנוהל בוועדות ערר), תשכ"ו – 1965 המפנות להגדרה שבתקנות שירותי הסעד (תפקיד מנהל ועדת הסעד), תשכ"ד – 1963.
#  - "הצדדים"::
#
#  - "העורר"::
#    מי שהגיש ערר בכתב לוועדת הערר או בא כוחו. מנהל המחלקה לשירותים חברתיים ברשות המקומית.
#  - "דו"ח תגובה לערר"::
#     מסמך הכולל את תמצית הנתונים הנוגעים בערר חתום על ידי מנהל המחלקה לשירותים חברתיים, כולל העתק התשובה לעורר בעניין.
#  - "טיפול סוציאלי"::
#     כל עזרה שאינה חומרית ואשר היא בתחום אחריותה של המחלקה לשירותים חברתיים.
#  - "סעד"::
#     עזרה חומרית ישירה או עקיפה, אותה המחלקה לשירותים חברתיים נותנת, שבגינה פורסמו כללי זכאות מוחלטים – לפי הוראות המנהל הכללי של משרד העבודה, הרווחה והשירותים החברתיים (תקנון עובדים סוציאליים). הליך מינוי חברי הוועדה המנהל הכללי של המשרד יקבל מאת מנהל המחלקה לוועדות ערר וסיוע לבודדים, הצעות למועמדים ויעבירם לשר הרווחה.
# 136:Document: 14.4 נגיש - https://docs.google.com/document/d/11kHHq0UhNMzk9o4u07cGKtS_4aD9bYnbAyVjK0JtYfg/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (מסגרת שיקומית וטיפולית עבור אנשים עם מוגבלות שכלית התפחותית כמפורט בסעיף 2 דלעיל תיפתח ותופעל אך ורק על פי חוק פיקוח על המעונות תשכ"ה – 1965 והתקנות הנלוות אליו.)
#  - חניך/חוסה::
#     אדם עם מוגבלות שכלית התפתחותית בכל גיל, אשר לשם הטיפול בו וקידומו האישי, שוהה באחת המסגרות המפורטות בהוראה זו.
#  - מסגרת יומית::
#
#  - פעוטון ומסגרות יום טיפוליים::
#    מסגרת יומית מיוחדת עבור אנשים עם מוגבלות שכלית התפתחותית בכל הגילים בעלי מוגבלות שכלית התפתחותית עמוקה ו/או סיעודיים.
#  - מעונות יום לבעלי מוגבלות שכלית התפתחותית בינונית::
#    מסגרות למוגבלים שכלית התפתחותית בגיל חינוך חובה בבתי ספר של משרד החינוך והתרבות, או מסגרות יום שבהשתתפותו.
#  - מע"ש::
#    מרכז עבודה ושיקום לאנשים עם מוגבלות שכלית התפתחותית בעלי מוגבלות שכלית התפתחותית בינונית ונמוכה.
#  - מסגרות דיור::
#
#  - מעון פנימייתי (ממשלתי ציבורי או פרטי)::
#    מקום המשמש כולו או בחלקו כמקום מגורים, או שהייה לאדם עם מוגבלות שכלית התפתחותית מחוץ למגורי משפחתו, כמפורט בחוק הפיקוח על המעונות תשכ"ה – 1965.
#  - מעון משפחתי – כמו מעון פנימיתי – ל::
#    6 עד 12 חוסים.
#  - משפחת אומנה – כמו מעון פנימיתי – ל::
#    1 עד 5 חוסים.
#  - הוסטל או דיור קהילתי::
#    כמו מעון פנימיתי לאוכלוסיה עד ל- 20 חוסים (דיירים).
#  - דירה::
#    כמו מעון פנימייתי – עד 6 חוסים.
#  - המחלקה::
#     המחלקה לשירותים חברתיים ברשות המקומית. אישור להפעלת המסגרות מסגרת שיקומית וטיפולית עבור אנשים עם מוגבלות שכלית התפחותית כמפורט בסעיף 2 דלעיל תיפתח ותופעל אך ורק על פי חוק פיקוח על המעונות תשכ"ה – 1965 והתקנות הנלוות אליו.
# 137:Document: 5.7 נגיש - https://docs.google.com/document/d/1SbeuYnZeWikPKuw8I-QlkyKiXa4MJpMnQjT_8Cl_5gI/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (שירותי תרגום/תמלול/העתקת סימנים ודיבור)
#  - קלינאי/ת תקשורת::
#     אדם שקיבל הכרה מטעם משרד הבריאות כקלינאי/ת תקשורת.
#  - לקות שמיעה::
#     פגיעה ביכולת השמיעה של לפחות dB 50 (על פי חישוב ממוצע סיפי השמיעה בתדרים 500 עד 4,000 הרץ (Hz) באוזן הטובה), שנקבעת על ידי בדיקה אודיולוגית ממכון שמיעה המוכר על ידי קופות החולים, והחתומה על ידי קלינאי/ת תקשורת.
#  - אודיוגרמה::
#     תוצאה של בדיקת שמיעה הנעשית במכון אודיולוגי על ידי קלינאי/ת תקשורת והחתומה על ידו/ה.
#  - נותן שירות::
#     ארגון המספק שירותי תמיכה לאנשים עם לקות שמיעה, שנבחר במכרז שמפרסם משרד העבודה הרווחה והשירותים החברתיים לעניין זה, מעת לעת.
#  - בעל תעודת עיוור/לקוי ראייה::
#     אדם שקיבל תעודת עיוור/לקוי ראייה בהתאם למפורט בהוראה 6.3 בתקנון עובדים סוציאליים.
#  - זקן::
#
#  - אדם שהגיע לגיל פרישה כהגדרתו בחוק גיל פרישה תשס"ד::
#    2004. סוגי שירותי תמיכה בתקשורת הזכאות למתן שירותי תמיכה בתקשורת המפורטים להלן תקבע על ידי קלינאי/ת התקשורת בשירות ראיה, שמיעה וטכנולוגיה במשרד העבודה, הרווחה והשירותים החברתיים על סמך המסמכים המפורטים בסעיף 4 להלן. שירותי תרגום/תמלול/העתקת סימנים ודיבור
# 138:Document: 8.3 נגיש - https://docs.google.com/document/d/1BQoHg5MBURaLChan4TDs7NZXJLhTERDtiteDfx2OoMQ/edit?usp=drivesdk
# 139:Document: 1.44 נגיש - https://docs.google.com/document/d/1K0h4HqvPKThLMon6kOvCUX4cuZzwEPLfMX8WxYD1vHw/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (ההתקשרויות עם מפעילי מסגרות חוץ ביתיות, על כל סוגיהן, הנן באחריות המשרד.)
#  - מסגרת דיור חוץ ביתית::
#     מבנה בו לקוחות המשרד יכולים לשהות בכל ימות השנה ולקבל טיפול בתחומי ההתמחות של המשרד, לפי הנחיותיו, במטרה לאפשר קיום ורווחה מיטביים ו/או מיצוי יכולתם ושיפור במצבם ותפקודם. כל מסגרת חייבת ברישוי על פי חוק ובהקצאת סמל המאפשר את ההתחשבנות עמה. קיימים שני סוגים של מסגרות:
#  - מסגרות אשר המגורים בהן ללא הגבלת זמן::
#    "בית לחיים" (מסגרות לאנשים עם מוגבלות, בתי אבות). מסגרות אשר המגורים בהן לזמן קצוב (פנימיות לילדים לנערים ולצעירים, מקלטים ומרכזי חירום לסוגיהם).
#  - השמה::
#     החלטת הוועדה (כפי שתפורט בנוהל זה) אודות המסגרת אליה יופנה הלקוח, באמצעות כתב התחייבות ("הועדה") לכיסוי עלות שהייתו של לקוח במסגרת לפי התעריף והתנאים שקבע המשרד.
#  - לקוח::
#
#  - לעניין נוהל זה::
#    קטין או בוגר בכל גיל ובכל מצב גופני או נפשי או שכלי המיועד לשילוב במסגרת חוץ ביתית.
#  - תכנון ההשמה::
#     תכנון ההשמה ייערך באמצעות ועדה לתכנון טיפול והערכה לגבי ילד ונוער ו/או ילד עם מוגבלות, וועדת אבחון ללקוח עם מוגבלות שכלית התפתחותית אשר קובעת את סוג המסגרת אליה יופנה האדם, ועדת אבחון למכורים או ועדה אחרת שמתמנה על ידי מנהל המחלקה ברשות המקומית, בה מתגורר הלקוח, שתפקידה לאשר את תכנית ההתערבות הכוללת המלצה לסידור חוץ ביתי כאפשרות המועדפת עבור הלקוח, ולקבוע את פרופיל המסגרת המתאימה לפרופיל הלקוח כאמור בסעיף 1.3.1 לעיל. סדר עבודתן של ועדות תכנון טיפול והערכה ילד ונוער מפורט בתקנון העובדים הסוציאליים 8.9.
#  - השמה חריגה::
#     כהגדרתה בסעיף 5.12 להלן.
#  - השמה בפועל::
#     איתור והתאמת המסגרת בפועל לצרכי הלקוח אשר תאושר על ידי ועדה מקומית במחלקה לשירותים חברתיים, ברשות בה מתגורר הלקוח המורכבת ממדר"צ או אחראי השמה ברשות ומעובד סוציאלי משפחה.
#  - ועדת הכרעה בין שירותית במטה המשרד::
# ...
#  - סעד::
#    עזרה חומרית ישירה או עקיפה שלגביה קיימים כללי 			זכאות.
#  - מקום מגורים::
#    כהגדרתו בתקנות שירותי הסעד (טיפול 			בנזקקים), התשמ"ו - 1986 (ראה הוראה 1.1 בתע"ס). נוהלי הפניה
# 629:Document: 1.1.17 - https://docs.google.com/document/d/1p3e06cDXqEGQt4ysw4-r73O8ATTv-36u9-V5SAi6ejE/edit?usp=drivesdk
#  - טיפול סוציאלי::
#    כל סוגי העזרה ושירותים סוציאליים למעט סעד.
#  - סעד::
#    עזרה חומרית ישירה או עקיפה שלגביה קיימים כללי 			זכאות.
#  - מקום מגורים::
#    כהגדרתו בתקנות שירותי הסעד (טיפול 	בנזקקים), התשמ"ו - 1986 (ראה הוראה 1.1 בתע"ס) "מקום שבו אוכל אדם וישן, ואם מחמת עבודתו הוא אוכל וישן מחוץ לדירתו אך מבקר בה לעיתים קרובות – דירתו: ואולם אם הוא משרת בצה"ל או מוחזק במעון או בבית סוהר, לא ייחשב מקום כאמור, בשל כך בלבד, למקום מגוריו". נוהלי הפניה
# 630:Document: 11.1.17 - https://docs.google.com/document/d/1WJYfkDcXXxK9JYE01O1Hs51LHKo_7OdmIhLFPatnrx4/edit?usp=drivesdk
#  - טיפול סוציאלי::
#    כל סוגי העזרה ושירותים סוציאליים למעט סעד.
#  - סעד::
#    עזרה חומרית ישירה או עקיפה שלגביה קיימים כללי 			זכאות.
#  - מקום מגורים::
#    כהגדרתו בתקנות שירותי הסעד (טיפול 	בנזקקים), התשמ"ו - 1986 (ראה הוראה 1.1 בתע"ס) "מקום שבו אוכל אדם וישן, ואם מחמת עבודתו הוא אוכל וישן מחוץ לדירתו אך מבקר בה לעיתים קרובות – דירתו: ואולם אם הוא משרת בצה"ל או מוחזק במעון או בבית סוהר, לא ייחשב מקום כאמור, בשל כך בלבד, למקום מגוריו". נוהלי הפניה
# 631:Document: 11 1 17 - https://docs.google.com/document/d/1ouuU8y0fUnKbgfY5etf1o5zgwr6ECyXpXgZGMzCPJbQ/edit?usp=drivesdk
#  - טיפול סוציאלי::
#    כל סוגי העזרה ושירותים סוציאליים למעט סעד.
#  - סעד::
#    עזרה חומרית ישירה או עקיפה שלגביה קיימים כללי 			 זכאות.
#  - מקום מגורים::
#    כהגדרתו בתקנות שירותי הסעד (טיפול בנזקקים), התשמ"ו - 1986 (ראה הוראה 1.1 בתע"ס) "מקום שבו אוכל אדם וישן, ואם מחמת עבודתו הוא אוכל וישן מחוץ לדירתו אך מבקר בה לעיתים קרובות – דירתו: ואולם אם הוא משרת בצה"ל או מוחזק במעון או בבית סוהר, לא ייחשב מקום כאמור, בשל כך בלבד, למקום מגוריו". נוהלי הפניה
# 632:Document: סמך מקצועי משפחה - https://docs.google.com/document/d/1Ke_Qmy6w2yRlOlq0p8R-_y3nlF99LB2tDSgMspTUD_g/edit?usp=drivesdk
# 633:Document: עדכון מתן שירותים באמצעות עובדים סמך מקצועיים המופעלים בתחום המשפחה - https://docs.google.com/document/d/1N4VaQ9JWhecJM5T8Y7Tt0bwERoRqL6PxmH-kY7ggmeM/edit?usp=drivesdk
# 634:Document: נופשון לעיוורים - https://docs.google.com/document/d/1uhv_inp0oO1uIS8bMujopfvw1rzUB-GmCA5ltg2-Scw/edit?usp=drivesdk
# 635:Document: השרות לעיוור -ועדה מקצועית עליונה - https://docs.google.com/document/d/1Yk_cvwl078ErjdWjvhFdKHLhNoIOadh6oHHmhNw84rs/edit?usp=drivesdk
# 635:ERROR: השרות לעיוור -ועדה מקצועית עליונה : IndexError string index out of range
#   - https://docs.google.com/document/d/1Yk_cvwl078ErjdWjvhFdKHLhNoIOadh6oHHmhNw84rs/edit?usp=drivesdk
# 635:ERROR: השרות לעיוור -ועדה מקצועית עליונה : IndexError string index out of range
#   - https://docs.google.com/document/d/1Yk_cvwl078ErjdWjvhFdKHLhNoIOadh6oHHmhNw84rs/edit?usp=drivesdk
# 635:ERROR: השרות לעיוור -ועדה מקצועית עליונה : IndexError string index out of range
#   - https://docs.google.com/document/d/1Yk_cvwl078ErjdWjvhFdKHLhNoIOadh6oHHmhNw84rs/edit?usp=drivesdk
# 636:Document: נוהל טיפול בבני נוער במסגרת מיתר - https://docs.google.com/document/d/1K9v1IKRcAYps9zEOzjMj26I_7ruTllVkiarS0hI3AEQ/edit?usp=drivesdk
#  - מרכז יום תומך רב::
#    תחומי (מית"ר) – מהווה מסגרת התערבות ייחודית, קצרת מועד ואינטנסיבית, הנמצאת על רצף השירותים הטיפוליים בקהילה. המסגרת הינה טיפולית, שיקומית, חינוכית, המופעלת באמצעות צוות רב מקצועי .
# 637:Document: נספח אפוטרופסות - https://docs.google.com/document/d/104AOFRVZlbFks6ET0_1tqb_T2hByBcLzKH_v0wFtJIM/edit?usp=drivesdk
# 638:Document: ילדיםיתומים 3.20 - https://docs.google.com/document/d/1FWwyOnVywSQvVRJwGLEK_q3neyArLqeo_FUswhiBU0o/edit?usp=drivesdk
# 639:Document: סדרי דין - https://docs.google.com/document/d/1MTZAlR5OL_BgofWnIizsQfQJ7_cwpiNUDTkCtprD680/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (בית המשפט המחוזי.)
#  - עובד סוציאלי לעניין סדרי דין::
#    עובד המחלקה לשרותים חברתיים, כשיר לעבודה סוציאלית כהגדרתו בחוק העובדים הסוציאליים התשנ"ו-1996, אשר נבחר לתפקיד זה על ידי מנהל/ת המחלקה, עבר בהצלחה הכשרה ייחודית לתפקיד זה ומונה ע"י שר הרווחה לצורך יישום החוקים השונים המפורטים בהמשך.
#  - עובד סוציאלי ראשי לעניין סדרי דין::
#    עובד סוציאלי כהגדרתו בחוק העובדים הסוציאליים התשנ"ו-1996, אשר מונה ע"י שר הרווחה לעניין חוק הסעד סדרי דין (בענייני קטינים חולי נפש ונעדרים), תשט"ו 1955.
#  - מפקח עובד סוציאלי מחוזי לעניין סדרי דין::
#    עובד סוציאלי כהגדרתו בחוק העובדים הסוציאליים התשנ"ו-1996, אשר מונה לעובד סוציאלי מחוזי לעניין סדרי דין ע"י שר הרווחה.
#  - יועץ משפטי::
#    יועץ משפטי במשרד הרווחה המשמש במסגרת הלשכה המשפטית לב"כ היועץ המשפטי לממשלה ומקום מושבו במשרד הראשי או במחוזות המשרד.
#  - ערכאה משפטית::
#    בית דין דתי. בית משפט השלום בית משפט לענייני משפחה. בית המשפט המחוזי.
# 640:Document: תפקידו ודרכי עבודתו של עובד סוציאלי לעניין סדרי דין 12 8 14 - https://docs.google.com/document/d/1EtrxNvkxu-7LtNY7mtStd08ZWE1VJAdD6Ggty2rS_pk/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (בית המשפט המחוזי.)
#  - עובד סוציאלי לעניין סדרי דין::
#    עובד המחלקה לשרותים חברתיים הרשום בפנקס העובדים הסוציאליים ואשר נבחר לתפקיד זה על ידי מנהל/ת המחלקה, עבר בהצלחה הכשרה ייחודית לתפקיד זה ומונה ע"י שר הרווחה והשירותים החברתיים לצורך יישום החוקים השונים המפורטים בהמשך.
#  - עובד סוציאלי ראשי לעניין סדרי דין::
#    עובד סוציאלי הרשום בפנקס העובדים הסוציאליים, אשר מונה ע"י שר הרווחה והשירותים החברתיים כעו"ס ראשי לעניין חוק הסעד סדרי דין (בענייני קטינים חולי נפש ונעדרים), תשט"ו - 1955.
#  - עובד סוציאלי מחוזי לעניין סדרי דין::
#    עובד סוציאלי הרשום בפנקס העובדים הסוציאליים, אשר מונה, ע"י שר הרווחה והשירותים החברתיים, כעובד סוציאלי מחוזי לעניין סדרי דין.
#  - יועץ משפטי::
#    יועץ משפטי במשרד הרווחה המשמש כב"כ היועץ המשפטי לממשלה ומקום מושבו במשרד הראשי או במחוזות המשרד.
#  - ערכאה משפטית::
#    בית דין דתי. בית משפט השלום בית משפט לענייני משפחה. בית המשפט המחוזי.
# 641:Document: מדיניות אוטיזם - https://docs.google.com/document/d/1k7DSZoqzaz-N6RONyjkMuMN_YxkTyYDLrzoZvE6-QcQ/edit?usp=drivesdk
# 642:Document: מדיניות הטיפול באנשים עם אוטיזם 10.1 - https://docs.google.com/document/d/1rL9KSX17fRLIBERrNK49JLJd2yFu3Bp9R_4kw6qmhQg/edit?usp=drivesdk
# 643:Document: קהילה נגישה - https://docs.google.com/document/d/146U5eRasV5WMBv9AQQZYW_9NWOLa5iF-fXHv0zVRi5Y/edit?usp=drivesdk
#  - "קהילה נגישה"::
#    תוכנית המופעלת ברשות המקומית, שמבוססת על התארגנות מקומית של אנשים עם מוגבלות, הפועלים בשותפות עם אנשי מקצוע בקהילה לצורך הגברת התאמת נגישות השרות והנגשה פיזית וחברתית וכדי לקדם השתלבות מלאה שלהם בחברה.
#  - "נגישות חברתית"::
#    התאמת הסביבה החברתית, פיתוח מודעות לאנשים עם מוגבלות ושינוי העמדות כלפיהם, המושגים על ידי פעולות שונות, כגון הסברה וחשיפה.
#  - "נגישות השירות"::
#    התאמת השירות לאדם עם מוגבלות, בהתייחס למוגבלויות השונות.
#  - "נגישות פיזית"::
#    אפשרות הגעה למקום, תנועה והתמצאות בו, שימוש במתקנים והשתתפות בתכניות ובפעילויות המתקיימות בהם, והכל באופן שוויוני, מכובד, עצמאי ובטיחותי (מתוך חוק שוויון זכויות לאנשים עם מוגבלות (תיקון מס' 2) , התשס"ה – 2005).
# 644:Document: סמך מקצועי 3 - https://docs.google.com/document/d/1vfiNNWEFB_FCbL98L0SXHRL-cYVfQnuO7rbFSmWgYmY/edit?usp=drivesdk
#  - עובד סמך::
#    מקצועי : עובד אשר מבצע משימות שונות, שהוגדרו על ידי העובד הסוציאלי במחלקה לשירותים חברתיים.
#  - נותן שירות ("אירגון")::
#    עמותה, או חברה, שזכתה במכרז של משרד הרווחה והשירותים החברתיים, למתן שירותי הכשרה, הדרכה, הפעלה ופיקוח על עובדי סמך מקצועיים וחתומה על הסכם (איזה הסכם? אפשר לרשם את השם שלו) עם המשרד (נספח א').
# 645:Document: הצעה 3 3 סמך מקצועי - https://docs.google.com/document/d/1LYXhiPvM7g9l3DIelQZeC5glH1srPIRuliTGvOgurVw/edit?usp=drivesdk
#  - עובד סמך::
#    מקצועי : עובד אשר מבצע משימות שונות, שהוגדרו על ידי העובד הסוציאלי במחלקה לשירותים חברתיים.
#  - נותן שירות ("ארגון")::
#    עמותה, או חברה, שזכתה במכרז של משרד הרווחה והשירותים החברתיים, למתן שירותי הכשרה, הדרכה, הפעלה ופיקוח על עובדי סמך מקצועיים וחתומה על הסכם למתן שירותים עם המשרד (נספח א').
# 646:Document: מתנדבים למיצוי זכויות שיל 18.5 - https://docs.google.com/document/d/1ZV7H8940m1d8QxP6pqZPOKQcPpJ-uUYw42_7i3EMxhw/edit?usp=drivesdk
# 647:Document: מתנדבים ברשומ 18.2 - https://docs.google.com/document/d/1P470o9S9QLXNXxVeny42Zt2zgCoTxBJePRvG92IoifQ/edit?usp=drivesdk
# 648:Document: מרכז יום טיפולי שיקומי - https://docs.google.com/document/d/1J4Qg3_xuZ7pvX2IBlr5JTHiYSc5f2giYZp0jlGhERSA/edit?usp=drivesdk
# 649:Document: קיטנהלמפגרים - https://docs.google.com/document/d/1lthZSPYJa3ZiImwApLnpvjW5jyNFtGMcj95dDjIgbVk/edit?usp=drivesdk
# 650:Document: קייטנות קיץ עדכון - https://docs.google.com/document/d/1MFQgvZWlcV7uCLFKvaOsiIh59SkiDmFfnvR7PwUI1Yw/edit?usp=drivesdk
# 651:Document: קייטנותקיץ - https://docs.google.com/document/d/1T8ZJmaYmTTHYgTSp9rrBPMGJE3ZhRUKcmzZemuZrYB0/edit?usp=drivesdk
# 652:Document: הוראה 5.7 - https://docs.google.com/document/d/15uKF3C3XnULyw1X2MTkpv0FkkNBVINAo6R--pt69YGI/edit?usp=drivesdk
# ERROR: too many errors in definitions
# (שירותי תרגום/ תמלול/העתקת סימנים)
#  - קלינאי/ת תקשורת::
#    אדם שקיבל מספר הכרה במעמד מטעם משרד הבריאות כקלינאי/ת תקשורת.
#  - לקות שמיעה::
#    פגיעה ביכולת השמיעה של לפחות dB 50 (עפ"י חישוב ממוצע סיפי השמיעה בתדרים 500 עד 4,000 הרץ (Hz) באוזן הטובה), שנקבעת ע"י בדיקה אודיולוגית ממכון שמיעה המוכר ע"י קופות החולים, והחתומה ע"י קלינאי/ת תקשורת.
#  - אודיוגרמה::
#    תוצאה של בדיקת שמיעה הנעשית במכון אודיולוגי על ידי קלינאי/ת תקשורת והחתומה על ידו/ה.
#  - נותן שירות::
#    ארגון למתן שירותי תמיכה לאנשים עם לקות שמיעה, שעמד בתנאי המכרז שמפרסם משרד הרווחה לעניין זה, מעת לעת.
#  - אדם עובד::
#    מי שעובד בשכר לפחות 20 שעות בשבוע.
#  - בעל תעודת עיוור/לקוי ראייה::
#    כהגדרתו בהוראה 6.3 בתע"ס.
#  - זקן::
#    כהגדרתו בסעיף 2.4 בהוראה 1.22 בתע"ס סוגי שירותי תמיכה לתקשורת הזכאות למתן שירותי תמיכה לתקשורת המפורטים להלן תקבע ע"י קלינאי/ת התקשורת הארצי/ת באגף השיקום במשרד הרווחה על סמך המסמכים המפורטים בסעיף 4 להלן. שירותי תרגום/ תמלול/העתקת סימנים
# 653:Document: אובדן פתאומי ושכול 3.11 - https://docs.google.com/document/d/1zcHTPGKr_jdMdr-q51QtYp4RIvrJmyuRUrB81HexxoU/edit?usp=drivesdk
#  - בן משפחה::
#    בן זוג, הורה או בן זוג של הורה, בן או בת, אח או אחות.
#  - בן זוג::
#    לרבות הידוע בציבור כבן זוג ובלבד שערב מותו גר עמו וניהל עמו משק בית משותף במשך שנתיים לפחות.
#  - תאונת דרכים::
#    כהגדרתה בחוק פיצויים לנפגעי תאונות דרכים התשל"ה 1975.
#  - נפגע תאונת דרכים::
#    אדם שנפטר כתוצאה מתאונת דרכים.
#  - עבירת המתה::
#    עבירות רצח והריגה בלבד (סעיף 298,300 לחוק העונשין) ולא: עבירת גרם מוות ברשלנות, מוות שנגרם כתוצאה מתאונת דרכים, תאונת עבודה , מפעולות איבה, או מוות במהלך שירות צבאי..
#  - נפגע עבירת המתה::
#    בן זוג, הורה או בן זוג של הורה, בן או בת, אח או אחות של מי שהעבירה גרמה למותו. ועדת זכאות נפגעי עבירות המתה ועדה המיועדת לנפגעי המתה המורכבת משלושה חברים שמינה שר הרווחה והשירותים החברתיים מינוי יו"ר הוועדה ייעשה ע"י שר הרווחה והשירותים החברתיים בהתייעצות עם שר המשפטים והוא יהיה עובד ציבור הכשיר להיות שופט בית המשפט המחוזי . שני חברים נוספים יהיו ממשרד הרווחה והשירותים החברתיים וקצין משטרה מאגף החקירות של משטרת ישראל לאחר התייעצות והמלצת השר לביטחון פנים.
#  - מרכז סיוע לנפגעי תאונות דרכים::
#    מסגרת המופעלת ע"י הרשות המקומית המאבחנת את מצב בני המשפחה השכולים ומתאימים להם את הטיפול.
#  - מרכז סיוע לנפגעי עבירות המתה::
#    מסכרת המופעלת ע"י ארגון מפעיל שזכה במכרז של משרד הרווחה והשירותים החברתיים המאבחנות את מצב בני המשפחה השכולים ומתאימים להם את הסיוע.
#  - ועדת היגוי בינמשרדית::
#    ועדה בה שותפים נציגי משרדי ממשלה, נציגי גופים ציבוריים אחרים הפועלים בתחום ונציגי לקוחות.
# 654:Document: דירת קלט1 - https://docs.google.com/document/d/1oUQ4TiucdllpL6IiN0kq1ADOKRPD2qTM68U9SggNznI/edit?usp=drivesdk
# 655:Document: 10.1.17 - https://docs.google.com/document/d/1zZSnDqOvETiJ6rurvWjf5wSsn5zSG1Cc_DUbz_7CKtE/edit?usp=drivesdk
# ERROR: too many errors in definitions
#